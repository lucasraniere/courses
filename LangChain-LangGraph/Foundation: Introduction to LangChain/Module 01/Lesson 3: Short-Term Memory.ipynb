# %% [markdown]
# ### __Short-Term Memory__

# %%
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents import create_agent
from dotenv import load_dotenv
load_dotenv()

agent = create_agent(
    model="gpt-5-nano",
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Lucas and my favorite color is purple.")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Lucas and my favorite color is purple.', additional_kwargs={}, response_metadata={}, id='c0621cfb-757f-413d-bab0-34b3a77b5284'),
#               AIMessage(content='Nice to meet you, Lucas! Purple is a great color—bold and versatile. What would you like to do today? I can help with things like:\n\n- Creating a purple color palette for design or art\n- Explaining color theory and how purple pairs with other colors\n- Suggesting purple-themed fashion, decor, or branding ideas\n- Brainstorming a purple-inspired project or activity\n\nTell me what you’re interested in, or share a goal and I’ll tailor things to you.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 493, 'prompt_tokens': 18, 'total_tokens': 511, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DhfRbnvlqSQlNA0ImjiUIi7YrzEni', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e4689-4701-7df0-a7d3-5add23ece28d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 493, 'total_tokens': 511, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})]}

# %%
question = HumanMessage(content="What is my name and favorite color?")

response = agent.invoke(
    {"messages": [question]},
    config
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Lucas and my favorite color is purple.', additional_kwargs={}, response_metadata={}, id='c0621cfb-757f-413d-bab0-34b3a77b5284'),
#               AIMessage(content='Nice to meet you, Lucas! Purple is a great color—bold and versatile. What would you like to do today? I can help with things like:\n\n- Creating a purple color palette for design or art\n- Explaining color theory and how purple pairs with other colors\n- Suggesting purple-themed fashion, decor, or branding ideas\n- Brainstorming a purple-inspired project or activity\n\nTell me what you’re interested in, or share a goal and I’ll tailor things to you.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 493, 'prompt_tokens': 18, 'total_tokens': 511, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DhfRbnvlqSQlNA0ImjiUIi7YrzEni', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e4689-4701-7df0-a7d3-5add23ece28d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 493, 'total_tokens': 511, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}}),
#               HumanMessage(content='What is my name and favorite color?', additional_kwargs={}, response_metadata={}, id='f80ddd0c-8fb8-428d-9c75-154e6a0f8b40'),
#               AIMessage(content='Your name is Lucas, and your favorite color is purple.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 213, 'prompt_tokens': 136, 'total_tokens': 349, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DhfT7hpTasxfamUNuKPIoJbIDTNj9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e468a-b16c-7a70-a714-8c2a88cc052d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 136, 'output_tokens': 213, 'total_tokens': 349, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}})]}
